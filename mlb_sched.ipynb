# %%
import requests
from bs4 import BeautifulSoup
import datetime
import time
from fantasy_baseball.functions import write_csv

# %%
BASE_URL = 'https://www.mlb.com/schedule/'
START_DATE = '2025-02-01'
END_DATE = '2025-09-29'
HEADERS = {'Connection': 'keep-alive',
    'Accept': 'application/json',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36',}
MONTH_DCT = {'Feb': '02',
            'Mar': '03',
            'Apr': '04',
            'May': '05',
            'Jun': '06',
            'Jul': '07',
            'Aug': '08',
            'Sep': '09'}

# %%
# Collect URL dates
start_dt = datetime.datetime.strptime(START_DATE, '%Y-%m-%d').date()
end_dt = datetime.datetime.strptime(END_DATE, '%Y-%m-%d').date()
num = (end_dt - start_dt).days
dates = []
for i in range(0, num):
    dt = start_dt + datetime.timedelta(days=i)
    if dt == end_dt:
        break
    else:
        dates.append(str(dt))

# %%
#Scrape away bb.
completed_dts = set()
lst = []
for dt in dates:
    if dt not in completed_dts:
        # Give the program a nap.
        time.sleep(0.5)
        # Collect the html.
        response = requests.get(BASE_URL + dt, headers=HEADERS)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Collect the table information.
        weekdays = [i.text for i in soup.find_all('div', attrs={'class': "ScheduleCollectionGridstyle__DateLabel-sc-c0iua4-5 iaVuoa"})]
        types = [i.text if i.text else 'Regular' for i in soup.find_all('div', attrs={'class': "ScheduleCollectionGridstyle__GameTypeLabel-sc-c0iua4-6 dTLQcW"})]

        game_dates = []
        for d in soup.find_all('div', attrs={'class': "ScheduleCollectionGridstyle__DateLabel-sc-c0iua4-5 fQIzmH"}):
            month, date = d.text.split(' ')
            str_date = f'2025-{MONTH_DCT[month]}-{date.zfill(2)}'
            completed_dts.add(str_date)
            game_dates.append({'date': str_date})

        games = []
        for game_table in soup.find_all('div', attrs={'class':"ScheduleCollectionGridstyle__SectionWrapper-sc-c0iua4-0 guIOQi"}):
            daily_game_lst = game_table.find_all('div', attrs={'class':"TeamMatchupLayerstyle__TeamMatchupLayerWrapper-sc-ouprud-0 gQznxP teammatchup-teaminfo"})
            daily_game_lst = [i.text for i in daily_game_lst]
            temp = []
            for game in daily_game_lst:
                if '@' in game:
                    home, away = game.split('@')
                    # OK, Clean it up.
                    if len(home) == 4:
                        home = home[0] + home[1]
                    else:
                        home = home[0] + home[1] + home[3]

                    if len(away) == 4:
                        away = away[0] + away[1]
                    else:
                        away = away[0] + away[1] + away[3]
                        
                    temp.append({'home': home, 'away': away})
            games.append(temp)

        # Link the elements.
        for i, j in enumerate(weekdays):
            d = {'date': game_dates[i]['date'], 'weekday': weekdays[i], 'game_type': types[i]}
            for v in games[i]:
                lst.append(dict(d)| v)

        # Tell me youre alive.
        for i in set(i['date'] for i in game_dates):
            print(f'Day completed ... ({i})')

print(f'Number of games capture ... ({len(lst)})')
# Out:
# Day completed ... (2025-02-18)
# Day completed ... (2025-02-20)
# Day completed ... (2025-02-19)
# Day completed ... (2025-02-23)
# Day completed ... (2025-02-22)
# Day completed ... (2025-02-21)
# Day completed ... (2025-02-26)
# Day completed ... (2025-02-25)
# Day completed ... (2025-02-24)
# Day completed ... (2025-03-01)
# Day completed ... (2025-02-28)
# Day completed ... (2025-02-27)
# Day completed ... (2025-03-04)
# Day completed ... (2025-03-03)
# Day completed ... (2025-03-02)
# Day completed ... (2025-03-06)
# Day completed ... (2025-03-05)
# Day completed ... (2025-03-07)
# Day completed ... (2025-03-08)
# Day completed ... (2025-03-10)
# Day completed ... (2025-03-09)
# Day completed ... (2025-03-11)
# Day completed ... (2025-03-13)
# Day completed ... (2025-03-12)
# Day completed ... (2025-03-14)
# Day completed ... (2025-03-15)
# Day completed ... (2025-03-16)
# Day completed ... (2025-03-18)
# Day completed ... (2025-03-19)
# Day completed ... (2025-03-17)
# Day completed ... (2025-03-21)
# Day completed ... (2025-03-22)
# Day completed ... (2025-03-20)
# Day completed ... (2025-03-24)
# Day completed ... (2025-03-25)
# Day completed ... (2025-03-23)
# Day completed ... (2025-03-27)
# Day completed ... (2025-03-26)
# Day completed ... (2025-03-28)
# Day completed ... (2025-03-30)
# Day completed ... (2025-03-29)
# Day completed ... (2025-03-31)
# Day completed ... (2025-04-01)
# Day completed ... (2025-04-03)
# Day completed ... (2025-04-02)
# Day completed ... (2025-04-06)
# Day completed ... (2025-04-04)
# Day completed ... (2025-04-05)
# Day completed ... (2025-04-08)
# Day completed ... (2025-04-09)
# Day completed ... (2025-04-07)
# Day completed ... (2025-04-10)
# Day completed ... (2025-04-12)
# Day completed ... (2025-04-11)
# Day completed ... (2025-04-13)
# Day completed ... (2025-04-14)
# Day completed ... (2025-04-15)
# Day completed ... (2025-04-16)
# Day completed ... (2025-04-18)
# Day completed ... (2025-04-17)
# Day completed ... (2025-04-20)
# Day completed ... (2025-04-19)
# Day completed ... (2025-04-21)
# Day completed ... (2025-04-24)
# Day completed ... (2025-04-23)
# Day completed ... (2025-04-22)
# Day completed ... (2025-04-27)
# Day completed ... (2025-04-25)
# Day completed ... (2025-04-26)
# Day completed ... (2025-04-29)
# Day completed ... (2025-04-30)
# Day completed ... (2025-04-28)
# Day completed ... (2025-05-03)
# Day completed ... (2025-05-02)
# Day completed ... (2025-05-01)
# Day completed ... (2025-05-04)
# Day completed ... (2025-05-05)
# Day completed ... (2025-05-06)
# Day completed ... (2025-05-08)
# Day completed ... (2025-05-09)
# Day completed ... (2025-05-07)
# Day completed ... (2025-05-12)
# Day completed ... (2025-05-10)
# Day completed ... (2025-05-11)
# Day completed ... (2025-05-14)
# Day completed ... (2025-05-13)
# Day completed ... (2025-05-15)
# Day completed ... (2025-05-16)
# Day completed ... (2025-05-18)
# Day completed ... (2025-05-17)
# Day completed ... (2025-05-20)
# Day completed ... (2025-05-19)
# Day completed ... (2025-05-21)
# Day completed ... (2025-05-24)
# Day completed ... (2025-05-23)
# Day completed ... (2025-05-22)
# Day completed ... (2025-05-25)
# Day completed ... (2025-05-26)
# Day completed ... (2025-05-27)
# Day completed ... (2025-05-30)
# Day completed ... (2025-05-29)
# Day completed ... (2025-05-28)
# Day completed ... (2025-05-31)
# Day completed ... (2025-06-02)
# Day completed ... (2025-06-01)
# Day completed ... (2025-06-03)
# Day completed ... (2025-06-04)
# Day completed ... (2025-06-05)
# Day completed ... (2025-06-06)
# Day completed ... (2025-06-07)
# Day completed ... (2025-06-08)
# Day completed ... (2025-06-10)
# Day completed ... (2025-06-09)
# Day completed ... (2025-06-11)
# Day completed ... (2025-06-12)
# Day completed ... (2025-06-14)
# Day completed ... (2025-06-13)
# Day completed ... (2025-06-15)
# Day completed ... (2025-06-17)
# Day completed ... (2025-06-16)
# Day completed ... (2025-06-20)
# Day completed ... (2025-06-19)
# Day completed ... (2025-06-18)
# Day completed ... (2025-06-22)
# Day completed ... (2025-06-23)
# Day completed ... (2025-06-21)
# Day completed ... (2025-06-25)
# Day completed ... (2025-06-24)
# Day completed ... (2025-06-26)
# Day completed ... (2025-06-29)
# Day completed ... (2025-06-27)
# Day completed ... (2025-06-28)
# Day completed ... (2025-06-30)
# Day completed ... (2025-07-02)
# Day completed ... (2025-07-01)
# Day completed ... (2025-07-03)
# Day completed ... (2025-07-04)
# Day completed ... (2025-07-05)
# Day completed ... (2025-07-08)
# Day completed ... (2025-07-07)
# Day completed ... (2025-07-06)
# Day completed ... (2025-07-11)
# Day completed ... (2025-07-10)
# Day completed ... (2025-07-09)
# Day completed ... (2025-07-13)
# Day completed ... (2025-07-12)
# Day completed ... (2025-07-14)
# Day completed ... (2025-07-17)
# Day completed ... (2025-07-15)
# Day completed ... (2025-07-16)
# Day completed ... (2025-07-19)
# Day completed ... (2025-07-18)
# Day completed ... (2025-07-20)
# Day completed ... (2025-07-23)
# Day completed ... (2025-07-22)
# Day completed ... (2025-07-21)
# Day completed ... (2025-07-25)
# Day completed ... (2025-07-26)
# Day completed ... (2025-07-24)
# Day completed ... (2025-07-28)
# Day completed ... (2025-07-27)
# Day completed ... (2025-07-29)
# Day completed ... (2025-08-01)
# Day completed ... (2025-07-30)
# Day completed ... (2025-07-31)
# Day completed ... (2025-08-04)
# Day completed ... (2025-08-02)
# Day completed ... (2025-08-03)
# Day completed ... (2025-08-05)
# Day completed ... (2025-08-07)
# Day completed ... (2025-08-06)
# Day completed ... (2025-08-08)
# Day completed ... (2025-08-09)
# Day completed ... (2025-08-10)
# Day completed ... (2025-08-12)
# Day completed ... (2025-08-13)
# Day completed ... (2025-08-11)
# Day completed ... (2025-08-16)
# Day completed ... (2025-08-15)
# Day completed ... (2025-08-14)
# Day completed ... (2025-08-17)
# Day completed ... (2025-08-18)
# Day completed ... (2025-08-19)
# Day completed ... (2025-08-22)
# Day completed ... (2025-08-20)
# Day completed ... (2025-08-21)
# Day completed ... (2025-08-23)
# Day completed ... (2025-08-25)
# Day completed ... (2025-08-24)
# Day completed ... (2025-08-26)
# Day completed ... (2025-08-27)
# Day completed ... (2025-08-28)
# Day completed ... (2025-08-31)
# Day completed ... (2025-08-29)
# Day completed ... (2025-08-30)
# Day completed ... (2025-09-02)
# Day completed ... (2025-09-01)
# Day completed ... (2025-09-03)
# Day completed ... (2025-09-06)
# Day completed ... (2025-09-04)
# Day completed ... (2025-09-05)
# Day completed ... (2025-09-09)
# Day completed ... (2025-09-08)
# Day completed ... (2025-09-07)
# Day completed ... (2025-09-12)
# Day completed ... (2025-09-10)
# Day completed ... (2025-09-11)
# Day completed ... (2025-09-14)
# Day completed ... (2025-09-15)
# Day completed ... (2025-09-13)
# Day completed ... (2025-09-16)
# Day completed ... (2025-09-17)
# Day completed ... (2025-09-18)
# Day completed ... (2025-09-20)
# Day completed ... (2025-09-21)
# Day completed ... (2025-09-19)
# Day completed ... (2025-09-24)
# Day completed ... (2025-09-22)
# Day completed ... (2025-09-23)
# Day completed ... (2025-09-26)
# Day completed ... (2025-09-27)
# Day completed ... (2025-09-25)
# Day completed ... (2025-09-28)
# Day completed ... (2025-09-30)
# Day completed ... (2025-09-29)
# Number of games capture ... (2931)

# %%
write_csv(file_path='C:\\Users\\peter\\Desktop\\vscode\\main\\fantasy_baseball\\.data\\2025_sched.csv', data=lst)
